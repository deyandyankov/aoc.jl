# %%
struct ShipDirection{x} end;
ShipDirection(x) = ShipDirection{x}()

mutable struct ShipState
    facing::ShipDirection
    x::Int
    y::Int
end

function get_instructions(filename)
    input = readlines(filename)
    instructions = map(input) do x
        instr = r"^([A-Z])([0-9]*)$"
        m = match(instr, x)
        (ShipDirection(Symbol(m[1])), parse(Int, m[2]))
    end
    instructions
end

# rotate right
function new_direction(facing::ShipDirection, d::ShipDirection{:R}, val)
    val % 90 != 0 && error("$(val) must be a multiple of 90")
    times = Int(val // 90)
    times > 4 && error("times direction cannot exceed 4")
    directions = [
        ShipDirection(:E),
        ShipDirection(:S),
        ShipDirection(:W),
        ShipDirection(:N),
        ShipDirection(:E),
        ShipDirection(:S),
        ShipDirection(:W),
        ShipDirection(:N)
    ]
    directions[findfirst(x -> x == facing, directions) + times]
end

# rotate left
function new_direction(facing::ShipDirection, d::ShipDirection{:L}, val)
    val % 90 != 0 && error("$(val) must be a multiple of 90")
    times = Int(val // 90)
    times > 4 && error("times direction cannot exceed 4")
    directions = [
        ShipDirection(:E),
        ShipDirection(:N),
        ShipDirection(:W),
        ShipDirection(:S),
        ShipDirection(:E),
        ShipDirection(:N),
        ShipDirection(:W),
        ShipDirection(:S)
    ]
    directions[findfirst(x -> x == facing, directions) + times]
end

new_position(facing::ShipDirection, d::ShipDirection{:E}, val) = [val, 0]
new_position(facing::ShipDirection, d::ShipDirection{:W}, val) = [-val, 0]
new_position(facing::ShipDirection, d::ShipDirection{:N}, val) = [0, val]
new_position(facing::ShipDirection, d::ShipDirection{:S}, val) = [0, -val]

new_position(facing::ShipDirection{:E}, d::ShipDirection{:F}, val) = [val, 0]
new_position(facing::ShipDirection{:W}, d::ShipDirection{:F}, val) = [-val, 0]
new_position(facing::ShipDirection{:N}, d::ShipDirection{:F}, val) = [0, val]
new_position(facing::ShipDirection{:S}, d::ShipDirection{:F}, val) = [0, -val]

function update!(s::ShipState, d::ShipDirection, val)
    np = new_position(s.facing, d, val)
    @show s, d, val
    s.x += np[1]
    s.y += np[2]
    @show s, d, val
end
function update!(s::ShipState, d::ShipDirection{:R}, val)
    nd = new_direction(s.facing, d, val)
    @show s, d, val, nd
    s.facing = nd
end
function update!(s::ShipState, d::ShipDirection{:L}, val)
    nd = new_direction(s.facing, d, val)
    @show s, d, val, nd
    s.facing = nd
end
# Out:
# update! (generic function with 3 methods)

# %%
shipState = ShipState(ShipDirection(:E), 0, 0);
instr = get_instructions("input/day12.txt");
instr
# Out:
# 787-element Array{Tuple{ShipDirection{_A} where _A,Int64},1}:
#  (ShipDirection{:F}(), 77)
#  (ShipDirection{:E}(), 4)
#  (ShipDirection{:S}(), 2)
#  (ShipDirection{:W}(), 1)
#  (ShipDirection{:L}(), 180)
#  (ShipDirection{:N}(), 4)
#  (ShipDirection{:R}(), 180)
#  (ShipDirection{:S}(), 3)
#  (ShipDirection{:W}(), 5)
#  (ShipDirection{:F}(), 86)
#  (ShipDirection{:L}(), 90)
#  (ShipDirection{:E}(), 1)
#  (ShipDirection{:F}(), 16)
#  ⋮
#  (ShipDirection{:F}(), 94)
#  (ShipDirection{:F}(), 85)
#  (ShipDirection{:R}(), 90)
#  (ShipDirection{:E}(), 4)
#  (ShipDirection{:W}(), 2)
#  (ShipDirection{:S}(), 2)
#  (ShipDirection{:L}(), 180)
#  (ShipDirection{:W}(), 4)
#  (ShipDirection{:F}(), 28)
#  (ShipDirection{:E}(), 3)
#  (ShipDirection{:N}(), 5)
#  (ShipDirection{:F}(), 53)

# %%
for (direction, val) in instr
    update!(shipState, direction, val)
end
# Out:
# (s, d, val) = (ShipState(ShipDirection{:E}(), 0, 0), ShipDirection{:F}(), 77)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 77, 0), ShipDirection{:F}(), 77)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 77, 0), ShipDirection{:E}(), 4)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 81, 0), ShipDirection{:E}(), 4)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 81, 0), ShipDirection{:S}(), 2)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 81, -2), ShipDirection{:S}(), 2)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 81, -2), ShipDirection{:W}(), 1)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 80, -2), ShipDirection{:W}(), 1)
# (s, d, val, nd) = (ShipState(ShipDirection{:E}(), 80, -2), ShipDirection{:L}(), 180, ShipDirection{:W}())
# (s, d, val) = (ShipState(ShipDirection{:W}(), 80, -2), ShipDirection{:N}(), 4)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 80, 2), ShipDirection{:N}(), 4)
# (s, d, val, nd) = (ShipState(ShipDirection{:W}(), 80, 2), ShipDirection{:R}(), 180, ShipDirection{:E}())
# (s, d, val) = (ShipState(ShipDirection{:E}(), 80, 2), ShipDirection{:S}(), 3)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 80, -1), ShipDirection{:S}(), 3)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 80, -1), ShipDirection{:W}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 75, -1), ShipDirection{:W}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 75, -1), ShipDirection{:F}(), 86)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 161, -1), ShipDirection{:F}(), 86)
# (s, d, val, nd) = (ShipState(ShipDirection{:E}(), 161, -1), ShipDirection{:L}(), 90, ShipDirection{:N}())
# (s, d, val) = (ShipState(ShipDirection{:N}(), 161, -1), ShipDirection{:E}(), 1)
# (s, d, val) = (ShipState(ShipDirection{:N}(), 162, -1), ShipDirection{:E}(), 1)
# (s, d, val) = (ShipState(ShipDirection{:N}(), 162, -1), ShipDirection{:F}(), 16)
# (s, d, val) = (ShipState(ShipDirection{:N}(), 162, 15), ShipDirection{:F}(), 16)
# (s, d, val, nd) = (ShipState(ShipDirection{:N}(), 162, 15), ShipDirection{:R}(), 90, ShipDirection{:E}())
# (s, d, val) = (ShipState(ShipDirection{:E}(), 162, 15), ShipDirection{:N}(), 1)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 162, 16), ShipDirection{:N}(), 1)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 162, 16), ShipDirection{:E}(), 1)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 163, 16), ShipDirection{:E}(), 1)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 163, 16), ShipDirection{:F}(), 86)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 249, 16), ShipDirection{:F}(), 86)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 249, 16), ShipDirection{:S}(), 1)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 249, 15), ShipDirection{:S}(), 1)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 249, 15), ShipDirection{:F}(), 36)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 285, 15), ShipDirection{:F}(), 36)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 285, 15), ShipDirection{:E}(), 2)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 287, 15), ShipDirection{:E}(), 2)
# (s, d, val, nd) = (ShipState(ShipDirection{:E}(), 287, 15), ShipDirection{:L}(), 180, ShipDirection{:W}())
# (s, d, val) = (ShipState(ShipDirection{:W}(), 287, 15), ShipDirection{:N}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 287, 20), ShipDirection{:N}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 287, 20), ShipDirection{:F}(), 46)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 241, 20), ShipDirection{:F}(), 46)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 241, 20), ShipDirection{:N}(), 1)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 241, 21), ShipDirection{:N}(), 1)
# (s, d, val, nd) = (ShipState(ShipDirection{:W}(), 241, 21), ShipDirection{:L}(), 90, ShipDirection{:S}())
# (s, d, val) = (ShipState(ShipDirection{:S}(), 241, 21), ShipDirection{:F}(), 43)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 241, -22), ShipDirection{:F}(), 43)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 241, -22), ShipDirection{:S}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 241, -27), ShipDirection{:S}(), 5)
# (s, d, val, nd) = (ShipState(ShipDirection{:S}(), 241, -27), ShipDirection{:R}(), 90, ShipDirection{:W}())
# (s, d, val) = (ShipState(ShipDirection{:W}(), 241, -27), ShipDirection{:F}(), 41)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 200, -27), ShipDirection{:F}(), 41)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 200, -27), ShipDirection{:W}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 195, -27), ShipDirection{:W}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 195, -27), ShipDirection{:N}(), 1)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 195, -26), ShipDirection{:N}(), 1)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 195, -26), ShipDirection{:F}(), 65)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 130, -26), ShipDirection{:F}(), 65)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 130, -26), ShipDirection{:E}(), 4)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 134, -26), ShipDirection{:E}(), 4)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 134, -26), ShipDirection{:N}(), 1)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 134, -25), ShipDirection{:N}(), 1)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 134, -25), ShipDirection{:W}(), 3)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 131, -25), ShipDirection{:W}(), 3)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 131, -25), ShipDirection{:F}(), 92)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 39, -25), ShipDirection{:F}(), 92)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 39, -25), ShipDirection{:N}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 39, -20), ShipDirection{:N}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 39, -20), ShipDirection{:F}(), 33)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 6, -20), ShipDirection{:F}(), 33)
# (s, d, val, nd) = (ShipState(ShipDirection{:W}(), 6, -20), ShipDirection{:R}(), 90, ShipDirection{:N}())
# (s, d, val) = (ShipState(ShipDirection{:N}(), 6, -20), ShipDirection{:S}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:N}(), 6, -25), ShipDirection{:S}(), 5)
# (s, d, val, nd) = (ShipState(ShipDirection{:N}(), 6, -25), ShipDirection{:L}(), 90, ShipDirection{:W}())
# (s, d, val) = (ShipState(ShipDirection{:W}(), 6, -25), ShipDirection{:W}(), 1)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 5, -25), ShipDirection{:W}(), 1)
# (s, d, val, nd) = (ShipState(ShipDirection{:W}(), 5, -25), ShipDirection{:R}(), 180, ShipDirection{:E}())
# (s, d, val, nd) = (ShipState(ShipDirection{:E}(), 5, -25), ShipDirection{:L}(), 90, ShipDirection{:N}())
# (s, d, val) = (ShipState(ShipDirection{:N}(), 5, -25), ShipDirection{:S}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:N}(), 5, -30), ShipDirection{:S}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:N}(), 5, -30), ShipDirection{:F}(), 27)
# (s, d, val) = (ShipState(ShipDirection{:N}(), 5, -3), ShipDirection{:F}(), 27)
# (s, d, val, nd) = (ShipState(ShipDirection{:N}(), 5, -3), ShipDirection{:R}(), 90, ShipDirection{:E}())
# (s, d, val) = (ShipState(ShipDirection{:E}(), 5, -3), ShipDirection{:N}(), 4)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 5, 1), ShipDirection{:N}(), 4)
# (s, d, val, nd) = (ShipState(ShipDirection{:E}(), 5, 1), ShipDirection{:R}(), 90, ShipDirection{:S}())
# (s, d, val) = (ShipState(ShipDirection{:S}(), 5, 1), ShipDirection{:F}(), 43)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 5, -42), ShipDirection{:F}(), 43)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 5, -42), ShipDirection{:E}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 10, -42), ShipDirection{:E}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 10, -42), ShipDirection{:S}(), 2)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 10, -44), ShipDirection{:S}(), 2)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 10, -44), ShipDirection{:F}(), 68)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 10, -112), ShipDirection{:F}(), 68)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 10, -112), ShipDirection{:N}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 10, -107), ShipDirection{:N}(), 5)
# (s, d, val, nd) = (ShipState(ShipDirection{:S}(), 10, -107), ShipDirection{:R}(), 90, ShipDirection{:W}())
# (s, d, val) = (ShipState(ShipDirection{:W}(), 10, -107), ShipDirection{:F}(), 68)
# (s, d, val) = (ShipState(ShipDirection{:W}(), -58, -107), ShipDirection{:F}(), 68)
# (s, d, val, nd) = (ShipState(ShipDirection{:W}(), -58, -107), ShipDirection{:R}(), 180, ShipDirection{:E}())
# (s, d, val) = (ShipState(ShipDirection{:E}(), -58, -107), ShipDirection{:S}(), 2)
# (s, d, val) = (ShipState(ShipDirection{:E}(), -58, -109), ShipDirection{:S}(), 2)
# (s, d, val) = (ShipState(ShipDirection{:E}(), -58, -109), ShipDirection{:E}(), 2)
# (s, d, val) = (ShipState(ShipDirection{:E}(), -56, -109), ShipDirection{:E}(), 2)
# (s, d, val) = (ShipState(ShipDirection{:E}(), -56, -109), ShipDirection{:S}(), 3)
# (s, d, val) = (ShipState(ShipDirection{:E}(), -56, -112), ShipDirection{:S}(), 3)
# (s, d, val) = (ShipState(ShipDirection{:E}(), -56, -112), ShipDirection{:F}(), 41)
# (s, d, val) = (ShipState(ShipDirection{:E}(), -15, -112), ShipDirection{:F}(), 41)
# (s, d, val, nd) = (ShipState(ShipDirection{:E}(), -15, -112), ShipDirection{:L}(), 180, ShipDirection{:W}())
# (s, d, val) = (ShipState(ShipDirection{:W}(), -15, -112), ShipDirection{:E}(), 3)
# (s, d, val) = (ShipState(ShipDirection{:W}(), -12, -112), ShipDirection{:E}(), 3)
# (s, d, val, nd) = (ShipState(ShipDirection{:W}(), -12, -112), ShipDirection{:R}(), 90, ShipDirection{:N}())
# (s, d, val) = (ShipState(ShipDirection{:N}(), -12, -112), ShipDirection{:F}(), 73)
# (s, d, val) = (ShipState(ShipDirection{:N}(), -12, -39), ShipDirection{:F}(), 73)
# (s, d, val, nd) = (ShipState(ShipDirection{:N}(), -12, -39), ShipDirection{:R}(), 90, ShipDirection{:E}())
# (s, d, val) = (ShipState(ShipDirection{:E}(), -12, -39), ShipDirection{:N}(), 1)
# (s, d, val) = (ShipState(ShipDirection{:E}(), -12, -38), ShipDirection{:N}(), 1)
# (s, d, val, nd) = (ShipState(ShipDirection{:E}(), -12, -38), ShipDirection{:L}(), 180, ShipDirection{:W}())
# (s, d, val) = (ShipState(ShipDirection{:W}(), -12, -38), ShipDirection{:N}(), 3)
# (s, d, val) = (ShipState(ShipDirection{:W}(), -12, -35), ShipDirection{:N}(), 3)
# (s, d, val, nd) = (ShipState(ShipDirection{:W}(), -12, -35), ShipDirection{:L}(), 180, ShipDirection{:E}())
# (s, d, val) = (ShipState(ShipDirection{:E}(), -12, -35), ShipDirection{:W}(), 3)
# (s, d, val) = (ShipState(ShipDirection{:E}(), -15, -35), ShipDirection{:W}(), 3)
# (s, d, val) = (ShipState(ShipDirection{:E}(), -15, -35), ShipDirection{:S}(), 1)
# (s, d, val) = (ShipState(ShipDirection{:E}(), -15, -36), ShipDirection{:S}(), 1)
# (s, d, val, nd) = (ShipState(ShipDirection{:E}(), -15, -36), ShipDirection{:R}(), 180, ShipDirection{:W}())
# (s, d, val) = (ShipState(ShipDirection{:W}(), -15, -36), ShipDirection{:N}(), 3)
# (s, d, val) = (ShipState(ShipDirection{:W}(), -15, -33), ShipDirection{:N}(), 3)
# (s, d, val) = (ShipState(ShipDirection{:W}(), -15, -33), ShipDirection{:F}(), 26)
# (s, d, val) = (ShipState(ShipDirection{:W}(), -41, -33), ShipDirection{:F}(), 26)
# (s, d, val) = (ShipState(ShipDirection{:W}(), -41, -33), ShipDirection{:N}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:W}(), -41, -28), ShipDirection{:N}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:W}(), -41, -28), ShipDirection{:F}(), 27)
# (s, d, val) = (ShipState(ShipDirection{:W}(), -68, -28), ShipDirection{:F}(), 27)
# (s, d, val, nd) = (ShipState(ShipDirection{:W}(), -68, -28), ShipDirection{:L}(), 90, ShipDirection{:S}())
# (s, d, val) = (ShipState(ShipDirection{:S}(), -68, -28), ShipDirection{:F}(), 30)
# (s, d, val) = (ShipState(ShipDirection{:S}(), -68, -58), ShipDirection{:F}(), 30)
# (s, d, val, nd) = (ShipState(ShipDirection{:S}(), -68, -58), ShipDirection{:R}(), 180, ShipDirection{:N}())
# (s, d, val) = (ShipState(ShipDirection{:N}(), -68, -58), ShipDirection{:N}(), 4)
# (s, d, val) = (ShipState(ShipDirection{:N}(), -68, -54), ShipDirection{:N}(), 4)
# (s, d, val, nd) = (ShipState(ShipDirection{:N}(), -68, -54), ShipDirection{:R}(), 90, ShipDirection{:E}())
# (s, d, val) = (ShipState(ShipDirection{:E}(), -68, -54), ShipDirection{:E}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:E}(), -63, -54), ShipDirection{:E}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:E}(), -63, -54), ShipDirection{:N}(), 1)
# (s, d, val) = (ShipState(ShipDirection{:E}(), -63, -53), ShipDirection{:N}(), 1)
# (s, d, val) = (ShipState(ShipDirection{:E}(), -63, -53), ShipDirection{:F}(), 70)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 7, -53), ShipDirection{:F}(), 70)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 7, -53), ShipDirection{:E}(), 1)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 8, -53), ShipDirection{:E}(), 1)
# (s, d, val, nd) = (ShipState(ShipDirection{:E}(), 8, -53), ShipDirection{:L}(), 90, ShipDirection{:N}())
# (s, d, val) = (ShipState(ShipDirection{:N}(), 8, -53), ShipDirection{:N}(), 3)
# (s, d, val) = (ShipState(ShipDirection{:N}(), 8, -50), ShipDirection{:N}(), 3)
# (s, d, val) = (ShipState(ShipDirection{:N}(), 8, -50), ShipDirection{:F}(), 100)
# (s, d, val) = (ShipState(ShipDirection{:N}(), 8, 50), ShipDirection{:F}(), 100)
# (s, d, val, nd) = (ShipState(ShipDirection{:N}(), 8, 50), ShipDirection{:L}(), 90, ShipDirection{:W}())
# (s, d, val) = (ShipState(ShipDirection{:W}(), 8, 50), ShipDirection{:E}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 13, 50), ShipDirection{:E}(), 5)
# (s, d, val, nd) = (ShipState(ShipDirection{:W}(), 13, 50), ShipDirection{:L}(), 90, ShipDirection{:S}())
# (s, d, val) = (ShipState(ShipDirection{:S}(), 13, 50), ShipDirection{:S}(), 2)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 13, 48), ShipDirection{:S}(), 2)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 13, 48), ShipDirection{:F}(), 85)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 13, -37), ShipDirection{:F}(), 85)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 13, -37), ShipDirection{:W}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 8, -37), ShipDirection{:W}(), 5)
# (s, d, val, nd) = (ShipState(ShipDirection{:S}(), 8, -37), ShipDirection{:R}(), 90, ShipDirection{:W}())
# (s, d, val) = (ShipState(ShipDirection{:W}(), 8, -37), ShipDirection{:F}(), 85)
# (s, d, val) = (ShipState(ShipDirection{:W}(), -77, -37), ShipDirection{:F}(), 85)
# (s, d, val) = (ShipState(ShipDirection{:W}(), -77, -37), ShipDirection{:E}(), 3)
# (s, d, val) = (ShipState(ShipDirection{:W}(), -74, -37), ShipDirection{:E}(), 3)
# (s, d, val, nd) = (ShipState(ShipDirection{:W}(), -74, -37), ShipDirection{:R}(), 90, ShipDirection{:N}())
# (s, d, val) = (ShipState(ShipDirection{:N}(), -74, -37), ShipDirection{:E}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:N}(), -69, -37), ShipDirection{:E}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:N}(), -69, -37), ShipDirection{:F}(), 41)
# (s, d, val) = (ShipState(ShipDirection{:N}(), -69, 4), ShipDirection{:F}(), 41)
# (s, d, val, nd) = (ShipState(ShipDirection{:N}(), -69, 4), ShipDirection{:R}(), 180, ShipDirection{:S}())
# (s, d, val) = (ShipState(ShipDirection{:S}(), -69, 4), ShipDirection{:S}(), 1)
# (s, d, val) = (ShipState(ShipDirection{:S}(), -69, 3), ShipDirection{:S}(), 1)
# (s, d, val, nd) = (ShipState(ShipDirection{:S}(), -69, 3), ShipDirection{:L}(), 90, ShipDirection{:E}())
# (s, d, val) = (ShipState(ShipDirection{:E}(), -69, 3), ShipDirection{:F}(), 93)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 24, 3), ShipDirection{:F}(), 93)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 24, 3), ShipDirection{:S}(), 1)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 24, 2), ShipDirection{:S}(), 1)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 24, 2), ShipDirection{:F}(), 7)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 31, 2), ShipDirection{:F}(), 7)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 31, 2), ShipDirection{:N}(), 3)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 31, 5), ShipDirection{:N}(), 3)
# (s, d, val, nd) = (ShipState(ShipDirection{:E}(), 31, 5), ShipDirection{:R}(), 270, ShipDirection{:N}())
# (s, d, val) = (ShipState(ShipDirection{:N}(), 31, 5), ShipDirection{:W}(), 4)
# (s, d, val) = (ShipState(ShipDirection{:N}(), 27, 5), ShipDirection{:W}(), 4)
# (s, d, val) = (ShipState(ShipDirection{:N}(), 27, 5), ShipDirection{:S}(), 1)
# (s, d, val) = (ShipState(ShipDirection{:N}(), 27, 4), ShipDirection{:S}(), 1)
# (s, d, val) = (ShipState(ShipDirection{:N}(), 27, 4), ShipDirection{:F}(), 47)
# (s, d, val) = (ShipState(ShipDirection{:N}(), 27, 51), ShipDirection{:F}(), 47)
# (s, d, val, nd) = (ShipState(ShipDirection{:N}(), 27, 51), ShipDirection{:R}(), 90, ShipDirection{:E}())
# (s, d, val) = (ShipState(ShipDirection{:E}(), 27, 51), ShipDirection{:N}(), 2)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 27, 53), ShipDirection{:N}(), 2)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 27, 53), ShipDirection{:W}(), 4)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 23, 53), ShipDirection{:W}(), 4)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 23, 53), ShipDirection{:F}(), 21)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 44, 53), ShipDirection{:F}(), 21)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 44, 53), ShipDirection{:S}(), 1)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 44, 52), ShipDirection{:S}(), 1)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 44, 52), ShipDirection{:W}(), 1)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 43, 52), ShipDirection{:W}(), 1)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 43, 52), ShipDirection{:F}(), 44)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 87, 52), ShipDirection{:F}(), 44)
# (s, d, val, nd) = (ShipState(ShipDirection{:E}(), 87, 52), ShipDirection{:L}(), 180, ShipDirection{:W}())
# (s, d, val) = (ShipState(ShipDirection{:W}(), 87, 52), ShipDirection{:E}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 92, 52), ShipDirection{:E}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 92, 52), ShipDirection{:N}(), 3)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 92, 55), ShipDirection{:N}(), 3)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 92, 55), ShipDirection{:W}(), 4)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 88, 55), ShipDirection{:W}(), 4)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 88, 55), ShipDirection{:F}(), 11)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 77, 55), ShipDirection{:F}(), 11)
# (s, d, val, nd) = (ShipState(ShipDirection{:W}(), 77, 55), ShipDirection{:L}(), 180, ShipDirection{:E}())
# (s, d, val) = (ShipState(ShipDirection{:E}(), 77, 55), ShipDirection{:E}(), 2)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 79, 55), ShipDirection{:E}(), 2)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 79, 55), ShipDirection{:F}(), 36)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 115, 55), ShipDirection{:F}(), 36)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 115, 55), ShipDirection{:W}(), 4)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 111, 55), ShipDirection{:W}(), 4)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 111, 55), ShipDirection{:F}(), 34)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 145, 55), ShipDirection{:F}(), 34)
# (s, d, val, nd) = (ShipState(ShipDirection{:E}(), 145, 55), ShipDirection{:R}(), 90, ShipDirection{:S}())
# (s, d, val) = (ShipState(ShipDirection{:S}(), 145, 55), ShipDirection{:F}(), 30)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 145, 25), ShipDirection{:F}(), 30)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 145, 25), ShipDirection{:N}(), 1)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 145, 26), ShipDirection{:N}(), 1)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 145, 26), ShipDirection{:E}(), 1)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 146, 26), ShipDirection{:E}(), 1)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 146, 26), ShipDirection{:F}(), 21)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 146, 5), ShipDirection{:F}(), 21)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 146, 5), ShipDirection{:N}(), 4)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 146, 9), ShipDirection{:N}(), 4)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 146, 9), ShipDirection{:F}(), 59)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 146, -50), ShipDirection{:F}(), 59)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 146, -50), ShipDirection{:E}(), 3)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 149, -50), ShipDirection{:E}(), 3)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 149, -50), ShipDirection{:F}(), 33)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 149, -83), ShipDirection{:F}(), 33)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 149, -83), ShipDirection{:N}(), 1)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 149, -82), ShipDirection{:N}(), 1)
# (s, d, val, nd) = (ShipState(ShipDirection{:S}(), 149, -82), ShipDirection{:L}(), 180, ShipDirection{:N}())
# (s, d, val) = (ShipState(ShipDirection{:N}(), 149, -82), ShipDirection{:W}(), 1)
# (s, d, val) = (ShipState(ShipDirection{:N}(), 148, -82), ShipDirection{:W}(), 1)
# (s, d, val, nd) = (ShipState(ShipDirection{:N}(), 148, -82), ShipDirection{:R}(), 90, ShipDirection{:E}())
# (s, d, val) = (ShipState(ShipDirection{:E}(), 148, -82), ShipDirection{:E}(), 3)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 151, -82), ShipDirection{:E}(), 3)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 151, -82), ShipDirection{:F}(), 84)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 235, -82), ShipDirection{:F}(), 84)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 235, -82), ShipDirection{:W}(), 3)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 232, -82), ShipDirection{:W}(), 3)
# (s, d, val, nd) = (ShipState(ShipDirection{:E}(), 232, -82), ShipDirection{:R}(), 90, ShipDirection{:S}())
# (s, d, val) = (ShipState(ShipDirection{:S}(), 232, -82), ShipDirection{:W}(), 1)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 231, -82), ShipDirection{:W}(), 1)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 231, -82), ShipDirection{:N}(), 1)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 231, -81), ShipDirection{:N}(), 1)
# (s, d, val, nd) = (ShipState(ShipDirection{:S}(), 231, -81), ShipDirection{:R}(), 90, ShipDirection{:W}())
# (s, d, val) = (ShipState(ShipDirection{:W}(), 231, -81), ShipDirection{:F}(), 27)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 204, -81), ShipDirection{:F}(), 27)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 204, -81), ShipDirection{:S}(), 3)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 204, -84), ShipDirection{:S}(), 3)
# (s, d, val, nd) = (ShipState(ShipDirection{:W}(), 204, -84), ShipDirection{:L}(), 90, ShipDirection{:S}())
# (s, d, val) = (ShipState(ShipDirection{:S}(), 204, -84), ShipDirection{:N}(), 4)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 204, -80), ShipDirection{:N}(), 4)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 204, -80), ShipDirection{:E}(), 3)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 207, -80), ShipDirection{:E}(), 3)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 207, -80), ShipDirection{:F}(), 97)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 207, -177), ShipDirection{:F}(), 97)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 207, -177), ShipDirection{:N}(), 3)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 207, -174), ShipDirection{:N}(), 3)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 207, -174), ShipDirection{:F}(), 30)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 207, -204), ShipDirection{:F}(), 30)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 207, -204), ShipDirection{:W}(), 3)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 204, -204), ShipDirection{:W}(), 3)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 204, -204), ShipDirection{:F}(), 77)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 204, -281), ShipDirection{:F}(), 77)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 204, -281), ShipDirection{:E}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 209, -281), ShipDirection{:E}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 209, -281), ShipDirection{:F}(), 1)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 209, -282), ShipDirection{:F}(), 1)
# (s, d, val, nd) = (ShipState(ShipDirection{:S}(), 209, -282), ShipDirection{:R}(), 90, ShipDirection{:W}())
# (s, d, val) = (ShipState(ShipDirection{:W}(), 209, -282), ShipDirection{:F}(), 96)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 113, -282), ShipDirection{:F}(), 96)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 113, -282), ShipDirection{:E}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 118, -282), ShipDirection{:E}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 118, -282), ShipDirection{:N}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 118, -277), ShipDirection{:N}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 118, -277), ShipDirection{:W}(), 2)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 116, -277), ShipDirection{:W}(), 2)
# (s, d, val, nd) = (ShipState(ShipDirection{:W}(), 116, -277), ShipDirection{:L}(), 90, ShipDirection{:S}())
# (s, d, val) = (ShipState(ShipDirection{:S}(), 116, -277), ShipDirection{:S}(), 1)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 116, -278), ShipDirection{:S}(), 1)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 116, -278), ShipDirection{:F}(), 46)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 116, -324), ShipDirection{:F}(), 46)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 116, -324), ShipDirection{:N}(), 4)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 116, -320), ShipDirection{:N}(), 4)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 116, -320), ShipDirection{:F}(), 41)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 116, -361), ShipDirection{:F}(), 41)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 116, -361), ShipDirection{:W}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 111, -361), ShipDirection{:W}(), 5)
# (s, d, val, nd) = (ShipState(ShipDirection{:S}(), 111, -361), ShipDirection{:L}(), 90, ShipDirection{:E}())
# (s, d, val) = (ShipState(ShipDirection{:E}(), 111, -361), ShipDirection{:S}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 111, -366), ShipDirection{:S}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 111, -366), ShipDirection{:F}(), 79)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 190, -366), ShipDirection{:F}(), 79)
# (s, d, val, nd) = (ShipState(ShipDirection{:E}(), 190, -366), ShipDirection{:R}(), 90, ShipDirection{:S}())
# (s, d, val) = (ShipState(ShipDirection{:S}(), 190, -366), ShipDirection{:F}(), 32)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 190, -398), ShipDirection{:F}(), 32)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 190, -398), ShipDirection{:S}(), 3)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 190, -401), ShipDirection{:S}(), 3)
# (s, d, val, nd) = (ShipState(ShipDirection{:S}(), 190, -401), ShipDirection{:R}(), 90, ShipDirection{:W}())
# (s, d, val) = (ShipState(ShipDirection{:W}(), 190, -401), ShipDirection{:F}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 185, -401), ShipDirection{:F}(), 5)
# (s, d, val, nd) = (ShipState(ShipDirection{:W}(), 185, -401), ShipDirection{:L}(), 90, ShipDirection{:S}())
# (s, d, val) = (ShipState(ShipDirection{:S}(), 185, -401), ShipDirection{:E}(), 1)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 186, -401), ShipDirection{:E}(), 1)
# (s, d, val, nd) = (ShipState(ShipDirection{:S}(), 186, -401), ShipDirection{:R}(), 180, ShipDirection{:N}())
# (s, d, val) = (ShipState(ShipDirection{:N}(), 186, -401), ShipDirection{:W}(), 2)
# (s, d, val) = (ShipState(ShipDirection{:N}(), 184, -401), ShipDirection{:W}(), 2)
# (s, d, val) = (ShipState(ShipDirection{:N}(), 184, -401), ShipDirection{:N}(), 3)
# (s, d, val) = (ShipState(ShipDirection{:N}(), 184, -398), ShipDirection{:N}(), 3)
# (s, d, val, nd) = (ShipState(ShipDirection{:N}(), 184, -398), ShipDirection{:L}(), 90, ShipDirection{:W}())
# (s, d, val) = (ShipState(ShipDirection{:W}(), 184, -398), ShipDirection{:S}(), 1)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 184, -399), ShipDirection{:S}(), 1)
# (s, d, val, nd) = (ShipState(ShipDirection{:W}(), 184, -399), ShipDirection{:R}(), 90, ShipDirection{:N}())
# (s, d, val) = (ShipState(ShipDirection{:N}(), 184, -399), ShipDirection{:W}(), 1)
# (s, d, val) = (ShipState(ShipDirection{:N}(), 183, -399), ShipDirection{:W}(), 1)
# (s, d, val) = (ShipState(ShipDirection{:N}(), 183, -399), ShipDirection{:F}(), 78)
# (s, d, val) = (ShipState(ShipDirection{:N}(), 183, -321), ShipDirection{:F}(), 78)
# (s, d, val) = (ShipState(ShipDirection{:N}(), 183, -321), ShipDirection{:W}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:N}(), 178, -321), ShipDirection{:W}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:N}(), 178, -321), ShipDirection{:N}(), 2)
# (s, d, val) = (ShipState(ShipDirection{:N}(), 178, -319), ShipDirection{:N}(), 2)
# (s, d, val) = (ShipState(ShipDirection{:N}(), 178, -319), ShipDirection{:E}(), 2)
# (s, d, val) = (ShipState(ShipDirection{:N}(), 180, -319), ShipDirection{:E}(), 2)
# (s, d, val, nd) = (ShipState(ShipDirection{:N}(), 180, -319), ShipDirection{:R}(), 90, ShipDirection{:E}())
# (s, d, val) = (ShipState(ShipDirection{:E}(), 180, -319), ShipDirection{:S}(), 4)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 180, -323), ShipDirection{:S}(), 4)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 180, -323), ShipDirection{:S}(), 2)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 180, -325), ShipDirection{:S}(), 2)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 180, -325), ShipDirection{:E}(), 4)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 184, -325), ShipDirection{:E}(), 4)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 184, -325), ShipDirection{:F}(), 59)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 243, -325), ShipDirection{:F}(), 59)
# (s, d, val, nd) = (ShipState(ShipDirection{:E}(), 243, -325), ShipDirection{:R}(), 270, ShipDirection{:N}())
# (s, d, val) = (ShipState(ShipDirection{:N}(), 243, -325), ShipDirection{:W}(), 2)
# (s, d, val) = (ShipState(ShipDirection{:N}(), 241, -325), ShipDirection{:W}(), 2)
# (s, d, val, nd) = (ShipState(ShipDirection{:N}(), 241, -325), ShipDirection{:L}(), 180, ShipDirection{:S}())
# (s, d, val) = (ShipState(ShipDirection{:S}(), 241, -325), ShipDirection{:S}(), 3)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 241, -328), ShipDirection{:S}(), 3)
# (s, d, val, nd) = (ShipState(ShipDirection{:S}(), 241, -328), ShipDirection{:R}(), 90, ShipDirection{:W}())
# (s, d, val) = (ShipState(ShipDirection{:W}(), 241, -328), ShipDirection{:W}(), 2)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 239, -328), ShipDirection{:W}(), 2)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 239, -328), ShipDirection{:F}(), 41)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 198, -328), ShipDirection{:F}(), 41)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 198, -328), ShipDirection{:N}(), 3)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 198, -325), ShipDirection{:N}(), 3)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 198, -325), ShipDirection{:F}(), 21)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 177, -325), ShipDirection{:F}(), 21)
# (s, d, val, nd) = (ShipState(ShipDirection{:W}(), 177, -325), ShipDirection{:L}(), 270, ShipDirection{:N}())
# (s, d, val) = (ShipState(ShipDirection{:N}(), 177, -325), ShipDirection{:F}(), 73)
# (s, d, val) = (ShipState(ShipDirection{:N}(), 177, -252), ShipDirection{:F}(), 73)
# (s, d, val) = (ShipState(ShipDirection{:N}(), 177, -252), ShipDirection{:N}(), 3)
# (s, d, val) = (ShipState(ShipDirection{:N}(), 177, -249), ShipDirection{:N}(), 3)
# (s, d, val) = (ShipState(ShipDirection{:N}(), 177, -249), ShipDirection{:E}(), 4)
# (s, d, val) = (ShipState(ShipDirection{:N}(), 181, -249), ShipDirection{:E}(), 4)
# (s, d, val, nd) = (ShipState(ShipDirection{:N}(), 181, -249), ShipDirection{:L}(), 90, ShipDirection{:W}())
# (s, d, val) = (ShipState(ShipDirection{:W}(), 181, -249), ShipDirection{:E}(), 3)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 184, -249), ShipDirection{:E}(), 3)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 184, -249), ShipDirection{:F}(), 97)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 87, -249), ShipDirection{:F}(), 97)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 87, -249), ShipDirection{:E}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 92, -249), ShipDirection{:E}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 92, -249), ShipDirection{:N}(), 4)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 92, -245), ShipDirection{:N}(), 4)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 92, -245), ShipDirection{:W}(), 4)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 88, -245), ShipDirection{:W}(), 4)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 88, -245), ShipDirection{:F}(), 42)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 46, -245), ShipDirection{:F}(), 42)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 46, -245), ShipDirection{:W}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 41, -245), ShipDirection{:W}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 41, -245), ShipDirection{:S}(), 3)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 41, -248), ShipDirection{:S}(), 3)
# (s, d, val, nd) = (ShipState(ShipDirection{:W}(), 41, -248), ShipDirection{:R}(), 180, ShipDirection{:E}())
# (s, d, val) = (ShipState(ShipDirection{:E}(), 41, -248), ShipDirection{:N}(), 1)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 41, -247), ShipDirection{:N}(), 1)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 41, -247), ShipDirection{:F}(), 56)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 97, -247), ShipDirection{:F}(), 56)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 97, -247), ShipDirection{:E}(), 2)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 99, -247), ShipDirection{:E}(), 2)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 99, -247), ShipDirection{:F}(), 23)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 122, -247), ShipDirection{:F}(), 23)
# (s, d, val, nd) = (ShipState(ShipDirection{:E}(), 122, -247), ShipDirection{:R}(), 90, ShipDirection{:S}())
# (s, d, val) = (ShipState(ShipDirection{:S}(), 122, -247), ShipDirection{:F}(), 37)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 122, -284), ShipDirection{:F}(), 37)
# (s, d, val, nd) = (ShipState(ShipDirection{:S}(), 122, -284), ShipDirection{:L}(), 90, ShipDirection{:E}())
# (s, d, val) = (ShipState(ShipDirection{:E}(), 122, -284), ShipDirection{:S}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 122, -289), ShipDirection{:S}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 122, -289), ShipDirection{:W}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 117, -289), ShipDirection{:W}(), 5)
# (s, d, val, nd) = (ShipState(ShipDirection{:E}(), 117, -289), ShipDirection{:R}(), 270, ShipDirection{:N}())
# (s, d, val) = (ShipState(ShipDirection{:N}(), 117, -289), ShipDirection{:E}(), 4)
# (s, d, val) = (ShipState(ShipDirection{:N}(), 121, -289), ShipDirection{:E}(), 4)
# (s, d, val) = (ShipState(ShipDirection{:N}(), 121, -289), ShipDirection{:F}(), 43)
# (s, d, val) = (ShipState(ShipDirection{:N}(), 121, -246), ShipDirection{:F}(), 43)
# (s, d, val) = (ShipState(ShipDirection{:N}(), 121, -246), ShipDirection{:W}(), 4)
# (s, d, val) = (ShipState(ShipDirection{:N}(), 117, -246), ShipDirection{:W}(), 4)
# (s, d, val, nd) = (ShipState(ShipDirection{:N}(), 117, -246), ShipDirection{:R}(), 90, ShipDirection{:E}())
# (s, d, val) = (ShipState(ShipDirection{:E}(), 117, -246), ShipDirection{:E}(), 3)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 120, -246), ShipDirection{:E}(), 3)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 120, -246), ShipDirection{:N}(), 2)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 120, -244), ShipDirection{:N}(), 2)
# (s, d, val, nd) = (ShipState(ShipDirection{:E}(), 120, -244), ShipDirection{:R}(), 90, ShipDirection{:S}())
# (s, d, val) = (ShipState(ShipDirection{:S}(), 120, -244), ShipDirection{:S}(), 4)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 120, -248), ShipDirection{:S}(), 4)
# (s, d, val, nd) = (ShipState(ShipDirection{:S}(), 120, -248), ShipDirection{:L}(), 90, ShipDirection{:E}())
# (s, d, val) = (ShipState(ShipDirection{:E}(), 120, -248), ShipDirection{:N}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 120, -243), ShipDirection{:N}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 120, -243), ShipDirection{:F}(), 52)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 172, -243), ShipDirection{:F}(), 52)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 172, -243), ShipDirection{:E}(), 3)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 175, -243), ShipDirection{:E}(), 3)
# (s, d, val, nd) = (ShipState(ShipDirection{:E}(), 175, -243), ShipDirection{:L}(), 90, ShipDirection{:N}())
# (s, d, val) = (ShipState(ShipDirection{:N}(), 175, -243), ShipDirection{:F}(), 18)
# (s, d, val) = (ShipState(ShipDirection{:N}(), 175, -225), ShipDirection{:F}(), 18)
# (s, d, val) = (ShipState(ShipDirection{:N}(), 175, -225), ShipDirection{:F}(), 89)
# (s, d, val) = (ShipState(ShipDirection{:N}(), 175, -136), ShipDirection{:F}(), 89)
# (s, d, val, nd) = (ShipState(ShipDirection{:N}(), 175, -136), ShipDirection{:L}(), 90, ShipDirection{:W}())
# (s, d, val) = (ShipState(ShipDirection{:W}(), 175, -136), ShipDirection{:W}(), 4)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 171, -136), ShipDirection{:W}(), 4)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 171, -136), ShipDirection{:F}(), 18)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 153, -136), ShipDirection{:F}(), 18)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 153, -136), ShipDirection{:E}(), 1)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 154, -136), ShipDirection{:E}(), 1)
# (s, d, val, nd) = (ShipState(ShipDirection{:W}(), 154, -136), ShipDirection{:L}(), 90, ShipDirection{:S}())
# (s, d, val) = (ShipState(ShipDirection{:S}(), 154, -136), ShipDirection{:E}(), 2)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 156, -136), ShipDirection{:E}(), 2)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 156, -136), ShipDirection{:F}(), 40)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 156, -176), ShipDirection{:F}(), 40)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 156, -176), ShipDirection{:F}(), 44)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 156, -220), ShipDirection{:F}(), 44)
# (s, d, val, nd) = (ShipState(ShipDirection{:S}(), 156, -220), ShipDirection{:R}(), 90, ShipDirection{:W}())
# (s, d, val) = (ShipState(ShipDirection{:W}(), 156, -220), ShipDirection{:N}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 156, -215), ShipDirection{:N}(), 5)
# (s, d, val, nd) = (ShipState(ShipDirection{:W}(), 156, -215), ShipDirection{:R}(), 90, ShipDirection{:N}())
# (s, d, val) = (ShipState(ShipDirection{:N}(), 156, -215), ShipDirection{:S}(), 1)
# (s, d, val) = (ShipState(ShipDirection{:N}(), 156, -216), ShipDirection{:S}(), 1)
# (s, d, val, nd) = (ShipState(ShipDirection{:N}(), 156, -216), ShipDirection{:L}(), 90, ShipDirection{:W}())
# (s, d, val) = (ShipState(ShipDirection{:W}(), 156, -216), ShipDirection{:F}(), 19)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 137, -216), ShipDirection{:F}(), 19)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 137, -216), ShipDirection{:N}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 137, -211), ShipDirection{:N}(), 5)
# (s, d, val, nd) = (ShipState(ShipDirection{:W}(), 137, -211), ShipDirection{:L}(), 180, ShipDirection{:E}())
# (s, d, val) = (ShipState(ShipDirection{:E}(), 137, -211), ShipDirection{:N}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 137, -206), ShipDirection{:N}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 137, -206), ShipDirection{:W}(), 3)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 134, -206), ShipDirection{:W}(), 3)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 134, -206), ShipDirection{:N}(), 4)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 134, -202), ShipDirection{:N}(), 4)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 134, -202), ShipDirection{:F}(), 73)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 207, -202), ShipDirection{:F}(), 73)
# (s, d, val, nd) = (ShipState(ShipDirection{:E}(), 207, -202), ShipDirection{:R}(), 90, ShipDirection{:S}())
# (s, d, val) = (ShipState(ShipDirection{:S}(), 207, -202), ShipDirection{:E}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 212, -202), ShipDirection{:E}(), 5)
# (s, d, val, nd) = (ShipState(ShipDirection{:S}(), 212, -202), ShipDirection{:R}(), 180, ShipDirection{:N}())
# (s, d, val) = (ShipState(ShipDirection{:N}(), 212, -202), ShipDirection{:F}(), 86)
# (s, d, val) = (ShipState(ShipDirection{:N}(), 212, -116), ShipDirection{:F}(), 86)
# (s, d, val) = (ShipState(ShipDirection{:N}(), 212, -116), ShipDirection{:E}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:N}(), 217, -116), ShipDirection{:E}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:N}(), 217, -116), ShipDirection{:S}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:N}(), 217, -121), ShipDirection{:S}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:N}(), 217, -121), ShipDirection{:F}(), 71)
# (s, d, val) = (ShipState(ShipDirection{:N}(), 217, -50), ShipDirection{:F}(), 71)
# (s, d, val) = (ShipState(ShipDirection{:N}(), 217, -50), ShipDirection{:W}(), 4)
# (s, d, val) = (ShipState(ShipDirection{:N}(), 213, -50), ShipDirection{:W}(), 4)
# (s, d, val) = (ShipState(ShipDirection{:N}(), 213, -50), ShipDirection{:F}(), 76)
# (s, d, val) = (ShipState(ShipDirection{:N}(), 213, 26), ShipDirection{:F}(), 76)
# (s, d, val) = (ShipState(ShipDirection{:N}(), 213, 26), ShipDirection{:S}(), 2)
# (s, d, val) = (ShipState(ShipDirection{:N}(), 213, 24), ShipDirection{:S}(), 2)
# (s, d, val, nd) = (ShipState(ShipDirection{:N}(), 213, 24), ShipDirection{:R}(), 180, ShipDirection{:S}())
# (s, d, val) = (ShipState(ShipDirection{:S}(), 213, 24), ShipDirection{:S}(), 1)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 213, 23), ShipDirection{:S}(), 1)
# (s, d, val, nd) = (ShipState(ShipDirection{:S}(), 213, 23), ShipDirection{:L}(), 90, ShipDirection{:E}())
# (s, d, val) = (ShipState(ShipDirection{:E}(), 213, 23), ShipDirection{:S}(), 2)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 213, 21), ShipDirection{:S}(), 2)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 213, 21), ShipDirection{:F}(), 67)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 280, 21), ShipDirection{:F}(), 67)
# (s, d, val, nd) = (ShipState(ShipDirection{:E}(), 280, 21), ShipDirection{:R}(), 90, ShipDirection{:S}())
# (s, d, val) = (ShipState(ShipDirection{:S}(), 280, 21), ShipDirection{:N}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 280, 26), ShipDirection{:N}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 280, 26), ShipDirection{:E}(), 1)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 281, 26), ShipDirection{:E}(), 1)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 281, 26), ShipDirection{:F}(), 100)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 281, -74), ShipDirection{:F}(), 100)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 281, -74), ShipDirection{:S}(), 3)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 281, -77), ShipDirection{:S}(), 3)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 281, -77), ShipDirection{:W}(), 3)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 278, -77), ShipDirection{:W}(), 3)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 278, -77), ShipDirection{:N}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 278, -72), ShipDirection{:N}(), 5)
# (s, d, val, nd) = (ShipState(ShipDirection{:S}(), 278, -72), ShipDirection{:R}(), 90, ShipDirection{:W}())
# (s, d, val) = (ShipState(ShipDirection{:W}(), 278, -72), ShipDirection{:F}(), 66)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 212, -72), ShipDirection{:F}(), 66)
# (s, d, val, nd) = (ShipState(ShipDirection{:W}(), 212, -72), ShipDirection{:L}(), 90, ShipDirection{:S}())
# (s, d, val) = (ShipState(ShipDirection{:S}(), 212, -72), ShipDirection{:E}(), 1)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 213, -72), ShipDirection{:E}(), 1)
# (s, d, val, nd) = (ShipState(ShipDirection{:S}(), 213, -72), ShipDirection{:L}(), 90, ShipDirection{:E}())
# (s, d, val) = (ShipState(ShipDirection{:E}(), 213, -72), ShipDirection{:W}(), 1)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 212, -72), ShipDirection{:W}(), 1)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 212, -72), ShipDirection{:F}(), 93)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 305, -72), ShipDirection{:F}(), 93)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 305, -72), ShipDirection{:S}(), 2)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 305, -74), ShipDirection{:S}(), 2)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 305, -74), ShipDirection{:F}(), 62)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 367, -74), ShipDirection{:F}(), 62)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 367, -74), ShipDirection{:F}(), 31)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 398, -74), ShipDirection{:F}(), 31)
# (s, d, val, nd) = (ShipState(ShipDirection{:E}(), 398, -74), ShipDirection{:L}(), 180, ShipDirection{:W}())
# (s, d, val) = (ShipState(ShipDirection{:W}(), 398, -74), ShipDirection{:F}(), 20)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 378, -74), ShipDirection{:F}(), 20)
# (s, d, val, nd) = (ShipState(ShipDirection{:W}(), 378, -74), ShipDirection{:R}(), 180, ShipDirection{:E}())
# (s, d, val) = (ShipState(ShipDirection{:E}(), 378, -74), ShipDirection{:F}(), 23)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 401, -74), ShipDirection{:F}(), 23)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 401, -74), ShipDirection{:W}(), 3)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 398, -74), ShipDirection{:W}(), 3)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 398, -74), ShipDirection{:F}(), 53)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 451, -74), ShipDirection{:F}(), 53)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 451, -74), ShipDirection{:W}(), 3)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 448, -74), ShipDirection{:W}(), 3)
# (s, d, val, nd) = (ShipState(ShipDirection{:E}(), 448, -74), ShipDirection{:R}(), 90, ShipDirection{:S}())
# (s, d, val) = (ShipState(ShipDirection{:S}(), 448, -74), ShipDirection{:E}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 453, -74), ShipDirection{:E}(), 5)
# (s, d, val, nd) = (ShipState(ShipDirection{:S}(), 453, -74), ShipDirection{:R}(), 90, ShipDirection{:W}())
# (s, d, val) = (ShipState(ShipDirection{:W}(), 453, -74), ShipDirection{:N}(), 3)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 453, -71), ShipDirection{:N}(), 3)
# (s, d, val, nd) = (ShipState(ShipDirection{:W}(), 453, -71), ShipDirection{:R}(), 90, ShipDirection{:N}())
# (s, d, val) = (ShipState(ShipDirection{:N}(), 453, -71), ShipDirection{:E}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:N}(), 458, -71), ShipDirection{:E}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:N}(), 458, -71), ShipDirection{:F}(), 11)
# (s, d, val) = (ShipState(ShipDirection{:N}(), 458, -60), ShipDirection{:F}(), 11)
# (s, d, val) = (ShipState(ShipDirection{:N}(), 458, -60), ShipDirection{:W}(), 4)
# (s, d, val) = (ShipState(ShipDirection{:N}(), 454, -60), ShipDirection{:W}(), 4)
# (s, d, val, nd) = (ShipState(ShipDirection{:N}(), 454, -60), ShipDirection{:R}(), 90, ShipDirection{:E}())
# (s, d, val) = (ShipState(ShipDirection{:E}(), 454, -60), ShipDirection{:W}(), 2)
# (s, d, val) = (ShipState(ShipDirection{:E}(), 452, -60), ShipDirection{:W}(), 2)
# (s, d, val, nd) = (ShipState(ShipDirection{:E}(), 452, -60), ShipDirection{:R}(), 180, ShipDirection{:W}())
# (s, d, val) = (ShipState(ShipDirection{:W}(), 452, -60), ShipDirection{:E}(), 3)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 455, -60), ShipDirection{:E}(), 3)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 455, -60), ShipDirection{:N}(), 4)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 455, -56), ShipDirection{:N}(), 4)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 455, -56), ShipDirection{:E}(), 3)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 458, -56), ShipDirection{:E}(), 3)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 458, -56), ShipDirection{:F}(), 88)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 370, -56), ShipDirection{:F}(), 88)
# (s, d, val, nd) = (ShipState(ShipDirection{:W}(), 370, -56), ShipDirection{:L}(), 90, ShipDirection{:S}())
# (s, d, val) = (ShipState(ShipDirection{:S}(), 370, -56), ShipDirection{:N}(), 2)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 370, -54), ShipDirection{:N}(), 2)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 370, -54), ShipDirection{:W}(), 1)
# (s, d, val) = (ShipState(ShipDirection{:S}(), 369, -54), ShipDirection{:W}(), 1)
# (s, d, val, nd) = (ShipState(ShipDirection{:S}(), 369, -54), ShipDirection{:R}(), 90, ShipDirection{:W}())
# (s, d, val) = (ShipState(ShipDirection{:W}(), 369, -54), ShipDirection{:F}(), 13)
# (s, d, val) = (ShipState(ShipDirection{:W}(), 356, -54), ShipDirection{:F}(), 13)
# ...
# (s, d, val, nd) = (ShipState(ShipDirection{:E}(), -900, -285), ShipDirection{:L}(), 90, ShipDirection{:N}())
# (s, d, val) = (ShipState(ShipDirection{:N}(), -900, -285), ShipDirection{:F}(), 35)
# (s, d, val) = (ShipState(ShipDirection{:N}(), -900, -250), ShipDirection{:F}(), 35)
# (s, d, val) = (ShipState(ShipDirection{:N}(), -900, -250), ShipDirection{:N}(), 2)
# (s, d, val) = (ShipState(ShipDirection{:N}(), -900, -248), ShipDirection{:N}(), 2)
# (s, d, val) = (ShipState(ShipDirection{:N}(), -900, -248), ShipDirection{:F}(), 52)
# (s, d, val) = (ShipState(ShipDirection{:N}(), -900, -196), ShipDirection{:F}(), 52)
# (s, d, val) = (ShipState(ShipDirection{:N}(), -900, -196), ShipDirection{:W}(), 1)
# (s, d, val) = (ShipState(ShipDirection{:N}(), -901, -196), ShipDirection{:W}(), 1)
# (s, d, val, nd) = (ShipState(ShipDirection{:N}(), -901, -196), ShipDirection{:L}(), 90, ShipDirection{:W}())
# (s, d, val) = (ShipState(ShipDirection{:W}(), -901, -196), ShipDirection{:F}(), 94)
# (s, d, val) = (ShipState(ShipDirection{:W}(), -995, -196), ShipDirection{:F}(), 94)
# (s, d, val) = (ShipState(ShipDirection{:W}(), -995, -196), ShipDirection{:N}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:W}(), -995, -191), ShipDirection{:N}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:W}(), -995, -191), ShipDirection{:E}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:W}(), -990, -191), ShipDirection{:E}(), 5)
# (s, d, val, nd) = (ShipState(ShipDirection{:W}(), -990, -191), ShipDirection{:R}(), 270, ShipDirection{:S}())
# (s, d, val) = (ShipState(ShipDirection{:S}(), -990, -191), ShipDirection{:N}(), 2)
# (s, d, val) = (ShipState(ShipDirection{:S}(), -990, -189), ShipDirection{:N}(), 2)
# (s, d, val, nd) = (ShipState(ShipDirection{:S}(), -990, -189), ShipDirection{:R}(), 180, ShipDirection{:N}())
# (s, d, val) = (ShipState(ShipDirection{:N}(), -990, -189), ShipDirection{:S}(), 2)
# (s, d, val) = (ShipState(ShipDirection{:N}(), -990, -191), ShipDirection{:S}(), 2)
# (s, d, val) = (ShipState(ShipDirection{:N}(), -990, -191), ShipDirection{:E}(), 2)
# (s, d, val) = (ShipState(ShipDirection{:N}(), -988, -191), ShipDirection{:E}(), 2)
# (s, d, val) = (ShipState(ShipDirection{:N}(), -988, -191), ShipDirection{:N}(), 2)
# (s, d, val) = (ShipState(ShipDirection{:N}(), -988, -189), ShipDirection{:N}(), 2)
# (s, d, val) = (ShipState(ShipDirection{:N}(), -988, -189), ShipDirection{:S}(), 3)
# (s, d, val) = (ShipState(ShipDirection{:N}(), -988, -192), ShipDirection{:S}(), 3)
# (s, d, val) = (ShipState(ShipDirection{:N}(), -988, -192), ShipDirection{:F}(), 86)
# (s, d, val) = (ShipState(ShipDirection{:N}(), -988, -106), ShipDirection{:F}(), 86)
# (s, d, val) = (ShipState(ShipDirection{:N}(), -988, -106), ShipDirection{:N}(), 1)
# (s, d, val) = (ShipState(ShipDirection{:N}(), -988, -105), ShipDirection{:N}(), 1)
# (s, d, val) = (ShipState(ShipDirection{:N}(), -988, -105), ShipDirection{:F}(), 54)
# (s, d, val) = (ShipState(ShipDirection{:N}(), -988, -51), ShipDirection{:F}(), 54)
# (s, d, val) = (ShipState(ShipDirection{:N}(), -988, -51), ShipDirection{:N}(), 1)
# (s, d, val) = (ShipState(ShipDirection{:N}(), -988, -50), ShipDirection{:N}(), 1)
# (s, d, val, nd) = (ShipState(ShipDirection{:N}(), -988, -50), ShipDirection{:L}(), 90, ShipDirection{:W}())
# (s, d, val) = (ShipState(ShipDirection{:W}(), -988, -50), ShipDirection{:W}(), 2)
# (s, d, val) = (ShipState(ShipDirection{:W}(), -990, -50), ShipDirection{:W}(), 2)
# (s, d, val, nd) = (ShipState(ShipDirection{:W}(), -990, -50), ShipDirection{:R}(), 90, ShipDirection{:N}())
# (s, d, val) = (ShipState(ShipDirection{:N}(), -990, -50), ShipDirection{:E}(), 4)
# (s, d, val) = (ShipState(ShipDirection{:N}(), -986, -50), ShipDirection{:E}(), 4)
# (s, d, val, nd) = (ShipState(ShipDirection{:N}(), -986, -50), ShipDirection{:R}(), 90, ShipDirection{:E}())
# (s, d, val) = (ShipState(ShipDirection{:E}(), -986, -50), ShipDirection{:N}(), 3)
# (s, d, val) = (ShipState(ShipDirection{:E}(), -986, -47), ShipDirection{:N}(), 3)
# (s, d, val, nd) = (ShipState(ShipDirection{:E}(), -986, -47), ShipDirection{:R}(), 90, ShipDirection{:S}())
# (s, d, val) = (ShipState(ShipDirection{:S}(), -986, -47), ShipDirection{:F}(), 30)
# (s, d, val) = (ShipState(ShipDirection{:S}(), -986, -77), ShipDirection{:F}(), 30)
# (s, d, val) = (ShipState(ShipDirection{:S}(), -986, -77), ShipDirection{:S}(), 4)
# (s, d, val) = (ShipState(ShipDirection{:S}(), -986, -81), ShipDirection{:S}(), 4)
# (s, d, val) = (ShipState(ShipDirection{:S}(), -986, -81), ShipDirection{:F}(), 98)
# (s, d, val) = (ShipState(ShipDirection{:S}(), -986, -179), ShipDirection{:F}(), 98)
# (s, d, val) = (ShipState(ShipDirection{:S}(), -986, -179), ShipDirection{:W}(), 2)
# (s, d, val) = (ShipState(ShipDirection{:S}(), -988, -179), ShipDirection{:W}(), 2)
# (s, d, val) = (ShipState(ShipDirection{:S}(), -988, -179), ShipDirection{:S}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:S}(), -988, -184), ShipDirection{:S}(), 5)
# (s, d, val, nd) = (ShipState(ShipDirection{:S}(), -988, -184), ShipDirection{:R}(), 90, ShipDirection{:W}())
# (s, d, val) = (ShipState(ShipDirection{:W}(), -988, -184), ShipDirection{:N}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:W}(), -988, -179), ShipDirection{:N}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:W}(), -988, -179), ShipDirection{:W}(), 2)
# (s, d, val) = (ShipState(ShipDirection{:W}(), -990, -179), ShipDirection{:W}(), 2)
# (s, d, val) = (ShipState(ShipDirection{:W}(), -990, -179), ShipDirection{:S}(), 1)
# (s, d, val) = (ShipState(ShipDirection{:W}(), -990, -180), ShipDirection{:S}(), 1)
# (s, d, val) = (ShipState(ShipDirection{:W}(), -990, -180), ShipDirection{:F}(), 36)
# (s, d, val) = (ShipState(ShipDirection{:W}(), -1026, -180), ShipDirection{:F}(), 36)
# (s, d, val) = (ShipState(ShipDirection{:W}(), -1026, -180), ShipDirection{:S}(), 3)
# (s, d, val) = (ShipState(ShipDirection{:W}(), -1026, -183), ShipDirection{:S}(), 3)
# (s, d, val, nd) = (ShipState(ShipDirection{:W}(), -1026, -183), ShipDirection{:R}(), 90, ShipDirection{:N}())
# (s, d, val) = (ShipState(ShipDirection{:N}(), -1026, -183), ShipDirection{:S}(), 1)
# (s, d, val) = (ShipState(ShipDirection{:N}(), -1026, -184), ShipDirection{:S}(), 1)
# (s, d, val) = (ShipState(ShipDirection{:N}(), -1026, -184), ShipDirection{:F}(), 84)
# (s, d, val) = (ShipState(ShipDirection{:N}(), -1026, -100), ShipDirection{:F}(), 84)
# (s, d, val) = (ShipState(ShipDirection{:N}(), -1026, -100), ShipDirection{:S}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:N}(), -1026, -105), ShipDirection{:S}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:N}(), -1026, -105), ShipDirection{:N}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:N}(), -1026, -100), ShipDirection{:N}(), 5)
# (s, d, val, nd) = (ShipState(ShipDirection{:N}(), -1026, -100), ShipDirection{:L}(), 180, ShipDirection{:S}())
# (s, d, val) = (ShipState(ShipDirection{:S}(), -1026, -100), ShipDirection{:F}(), 16)
# (s, d, val) = (ShipState(ShipDirection{:S}(), -1026, -116), ShipDirection{:F}(), 16)
# (s, d, val) = (ShipState(ShipDirection{:S}(), -1026, -116), ShipDirection{:N}(), 1)
# (s, d, val) = (ShipState(ShipDirection{:S}(), -1026, -115), ShipDirection{:N}(), 1)
# (s, d, val) = (ShipState(ShipDirection{:S}(), -1026, -115), ShipDirection{:F}(), 55)
# (s, d, val) = (ShipState(ShipDirection{:S}(), -1026, -170), ShipDirection{:F}(), 55)
# (s, d, val, nd) = (ShipState(ShipDirection{:S}(), -1026, -170), ShipDirection{:L}(), 90, ShipDirection{:E}())
# (s, d, val) = (ShipState(ShipDirection{:E}(), -1026, -170), ShipDirection{:N}(), 4)
# (s, d, val) = (ShipState(ShipDirection{:E}(), -1026, -166), ShipDirection{:N}(), 4)
# (s, d, val) = (ShipState(ShipDirection{:E}(), -1026, -166), ShipDirection{:S}(), 2)
# (s, d, val) = (ShipState(ShipDirection{:E}(), -1026, -168), ShipDirection{:S}(), 2)
# (s, d, val) = (ShipState(ShipDirection{:E}(), -1026, -168), ShipDirection{:S}(), 3)
# (s, d, val) = (ShipState(ShipDirection{:E}(), -1026, -171), ShipDirection{:S}(), 3)
# (s, d, val, nd) = (ShipState(ShipDirection{:E}(), -1026, -171), ShipDirection{:R}(), 90, ShipDirection{:S}())
# (s, d, val) = (ShipState(ShipDirection{:S}(), -1026, -171), ShipDirection{:S}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:S}(), -1026, -176), ShipDirection{:S}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:S}(), -1026, -176), ShipDirection{:W}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:S}(), -1031, -176), ShipDirection{:W}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:S}(), -1031, -176), ShipDirection{:N}(), 1)
# (s, d, val) = (ShipState(ShipDirection{:S}(), -1031, -175), ShipDirection{:N}(), 1)
# (s, d, val) = (ShipState(ShipDirection{:S}(), -1031, -175), ShipDirection{:E}(), 4)
# (s, d, val) = (ShipState(ShipDirection{:S}(), -1027, -175), ShipDirection{:E}(), 4)
# (s, d, val) = (ShipState(ShipDirection{:S}(), -1027, -175), ShipDirection{:S}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:S}(), -1027, -180), ShipDirection{:S}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:S}(), -1027, -180), ShipDirection{:W}(), 1)
# (s, d, val) = (ShipState(ShipDirection{:S}(), -1028, -180), ShipDirection{:W}(), 1)
# (s, d, val, nd) = (ShipState(ShipDirection{:S}(), -1028, -180), ShipDirection{:L}(), 180, ShipDirection{:N}())
# (s, d, val) = (ShipState(ShipDirection{:N}(), -1028, -180), ShipDirection{:F}(), 100)
# (s, d, val) = (ShipState(ShipDirection{:N}(), -1028, -80), ShipDirection{:F}(), 100)
# (s, d, val) = (ShipState(ShipDirection{:N}(), -1028, -80), ShipDirection{:E}(), 4)
# (s, d, val) = (ShipState(ShipDirection{:N}(), -1024, -80), ShipDirection{:E}(), 4)
# (s, d, val) = (ShipState(ShipDirection{:N}(), -1024, -80), ShipDirection{:S}(), 3)
# (s, d, val) = (ShipState(ShipDirection{:N}(), -1024, -83), ShipDirection{:S}(), 3)
# (s, d, val) = (ShipState(ShipDirection{:N}(), -1024, -83), ShipDirection{:E}(), 3)
# (s, d, val) = (ShipState(ShipDirection{:N}(), -1021, -83), ShipDirection{:E}(), 3)
# (s, d, val) = (ShipState(ShipDirection{:N}(), -1021, -83), ShipDirection{:N}(), 3)
# (s, d, val) = (ShipState(ShipDirection{:N}(), -1021, -80), ShipDirection{:N}(), 3)
# (s, d, val) = (ShipState(ShipDirection{:N}(), -1021, -80), ShipDirection{:E}(), 1)
# (s, d, val) = (ShipState(ShipDirection{:N}(), -1020, -80), ShipDirection{:E}(), 1)
# (s, d, val, nd) = (ShipState(ShipDirection{:N}(), -1020, -80), ShipDirection{:L}(), 90, ShipDirection{:W}())
# (s, d, val) = (ShipState(ShipDirection{:W}(), -1020, -80), ShipDirection{:W}(), 4)
# (s, d, val) = (ShipState(ShipDirection{:W}(), -1024, -80), ShipDirection{:W}(), 4)
# (s, d, val) = (ShipState(ShipDirection{:W}(), -1024, -80), ShipDirection{:F}(), 60)
# (s, d, val) = (ShipState(ShipDirection{:W}(), -1084, -80), ShipDirection{:F}(), 60)
# (s, d, val) = (ShipState(ShipDirection{:W}(), -1084, -80), ShipDirection{:W}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:W}(), -1089, -80), ShipDirection{:W}(), 5)
# (s, d, val, nd) = (ShipState(ShipDirection{:W}(), -1089, -80), ShipDirection{:L}(), 270, ShipDirection{:N}())
# (s, d, val) = (ShipState(ShipDirection{:N}(), -1089, -80), ShipDirection{:W}(), 1)
# (s, d, val) = (ShipState(ShipDirection{:N}(), -1090, -80), ShipDirection{:W}(), 1)
# (s, d, val) = (ShipState(ShipDirection{:N}(), -1090, -80), ShipDirection{:S}(), 2)
# (s, d, val) = (ShipState(ShipDirection{:N}(), -1090, -82), ShipDirection{:S}(), 2)
# (s, d, val, nd) = (ShipState(ShipDirection{:N}(), -1090, -82), ShipDirection{:L}(), 90, ShipDirection{:W}())
# (s, d, val, nd) = (ShipState(ShipDirection{:W}(), -1090, -82), ShipDirection{:R}(), 90, ShipDirection{:N}())
# (s, d, val) = (ShipState(ShipDirection{:N}(), -1090, -82), ShipDirection{:F}(), 52)
# (s, d, val) = (ShipState(ShipDirection{:N}(), -1090, -30), ShipDirection{:F}(), 52)
# (s, d, val) = (ShipState(ShipDirection{:N}(), -1090, -30), ShipDirection{:S}(), 1)
# (s, d, val) = (ShipState(ShipDirection{:N}(), -1090, -31), ShipDirection{:S}(), 1)
# (s, d, val) = (ShipState(ShipDirection{:N}(), -1090, -31), ShipDirection{:W}(), 3)
# (s, d, val) = (ShipState(ShipDirection{:N}(), -1093, -31), ShipDirection{:W}(), 3)
# (s, d, val) = (ShipState(ShipDirection{:N}(), -1093, -31), ShipDirection{:N}(), 4)
# (s, d, val) = (ShipState(ShipDirection{:N}(), -1093, -27), ShipDirection{:N}(), 4)
# (s, d, val) = (ShipState(ShipDirection{:N}(), -1093, -27), ShipDirection{:F}(), 30)
# (s, d, val) = (ShipState(ShipDirection{:N}(), -1093, 3), ShipDirection{:F}(), 30)
# (s, d, val) = (ShipState(ShipDirection{:N}(), -1093, 3), ShipDirection{:E}(), 2)
# (s, d, val) = (ShipState(ShipDirection{:N}(), -1091, 3), ShipDirection{:E}(), 2)
# (s, d, val) = (ShipState(ShipDirection{:N}(), -1091, 3), ShipDirection{:F}(), 9)
# (s, d, val) = (ShipState(ShipDirection{:N}(), -1091, 12), ShipDirection{:F}(), 9)
# (s, d, val) = (ShipState(ShipDirection{:N}(), -1091, 12), ShipDirection{:F}(), 87)
# (s, d, val) = (ShipState(ShipDirection{:N}(), -1091, 99), ShipDirection{:F}(), 87)
# (s, d, val) = (ShipState(ShipDirection{:N}(), -1091, 99), ShipDirection{:S}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:N}(), -1091, 94), ShipDirection{:S}(), 5)
# (s, d, val, nd) = (ShipState(ShipDirection{:N}(), -1091, 94), ShipDirection{:R}(), 90, ShipDirection{:E}())
# (s, d, val) = (ShipState(ShipDirection{:E}(), -1091, 94), ShipDirection{:S}(), 4)
# (s, d, val) = (ShipState(ShipDirection{:E}(), -1091, 90), ShipDirection{:S}(), 4)
# (s, d, val) = (ShipState(ShipDirection{:E}(), -1091, 90), ShipDirection{:W}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:E}(), -1096, 90), ShipDirection{:W}(), 5)
# (s, d, val, nd) = (ShipState(ShipDirection{:E}(), -1096, 90), ShipDirection{:R}(), 180, ShipDirection{:W}())
# (s, d, val) = (ShipState(ShipDirection{:W}(), -1096, 90), ShipDirection{:S}(), 3)
# (s, d, val) = (ShipState(ShipDirection{:W}(), -1096, 87), ShipDirection{:S}(), 3)
# (s, d, val) = (ShipState(ShipDirection{:W}(), -1096, 87), ShipDirection{:E}(), 4)
# (s, d, val) = (ShipState(ShipDirection{:W}(), -1092, 87), ShipDirection{:E}(), 4)
# (s, d, val) = (ShipState(ShipDirection{:W}(), -1092, 87), ShipDirection{:S}(), 4)
# (s, d, val) = (ShipState(ShipDirection{:W}(), -1092, 83), ShipDirection{:S}(), 4)
# (s, d, val, nd) = (ShipState(ShipDirection{:W}(), -1092, 83), ShipDirection{:L}(), 90, ShipDirection{:S}())
# (s, d, val) = (ShipState(ShipDirection{:S}(), -1092, 83), ShipDirection{:W}(), 3)
# (s, d, val) = (ShipState(ShipDirection{:S}(), -1095, 83), ShipDirection{:W}(), 3)
# (s, d, val) = (ShipState(ShipDirection{:S}(), -1095, 83), ShipDirection{:F}(), 94)
# (s, d, val) = (ShipState(ShipDirection{:S}(), -1095, -11), ShipDirection{:F}(), 94)
# (s, d, val) = (ShipState(ShipDirection{:S}(), -1095, -11), ShipDirection{:F}(), 85)
# (s, d, val) = (ShipState(ShipDirection{:S}(), -1095, -96), ShipDirection{:F}(), 85)
# (s, d, val, nd) = (ShipState(ShipDirection{:S}(), -1095, -96), ShipDirection{:R}(), 90, ShipDirection{:W}())
# (s, d, val) = (ShipState(ShipDirection{:W}(), -1095, -96), ShipDirection{:E}(), 4)
# (s, d, val) = (ShipState(ShipDirection{:W}(), -1091, -96), ShipDirection{:E}(), 4)
# (s, d, val) = (ShipState(ShipDirection{:W}(), -1091, -96), ShipDirection{:W}(), 2)
# (s, d, val) = (ShipState(ShipDirection{:W}(), -1093, -96), ShipDirection{:W}(), 2)
# (s, d, val) = (ShipState(ShipDirection{:W}(), -1093, -96), ShipDirection{:S}(), 2)
# (s, d, val) = (ShipState(ShipDirection{:W}(), -1093, -98), ShipDirection{:S}(), 2)
# (s, d, val, nd) = (ShipState(ShipDirection{:W}(), -1093, -98), ShipDirection{:L}(), 180, ShipDirection{:E}())
# (s, d, val) = (ShipState(ShipDirection{:E}(), -1093, -98), ShipDirection{:W}(), 4)
# (s, d, val) = (ShipState(ShipDirection{:E}(), -1097, -98), ShipDirection{:W}(), 4)
# (s, d, val) = (ShipState(ShipDirection{:E}(), -1097, -98), ShipDirection{:F}(), 28)
# (s, d, val) = (ShipState(ShipDirection{:E}(), -1069, -98), ShipDirection{:F}(), 28)
# (s, d, val) = (ShipState(ShipDirection{:E}(), -1069, -98), ShipDirection{:E}(), 3)
# (s, d, val) = (ShipState(ShipDirection{:E}(), -1066, -98), ShipDirection{:E}(), 3)
# (s, d, val) = (ShipState(ShipDirection{:E}(), -1066, -98), ShipDirection{:N}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:E}(), -1066, -93), ShipDirection{:N}(), 5)
# (s, d, val) = (ShipState(ShipDirection{:E}(), -1066, -93), ShipDirection{:F}(), 53)
# (s, d, val) = (ShipState(ShipDirection{:E}(), -1013, -93), ShipDirection{:F}(), 53)

# %%
abs(shipState.x) + abs(shipState.y)
# Out:
# 1106
